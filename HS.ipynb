# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("C:/Users/lenovo/Downloads/sleeptime_prediction_dataset.csv")

# %%
data
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0            1.12         0.52       3.29       7.89          216.08
# 1            2.85         0.49       4.22       5.03          206.18
# 2            2.20         1.81       4.04       9.23           28.73
# 3            1.80         0.50       1.62       7.68          276.77
# 4            0.47         0.54       1.60       4.94          170.54
# ...           ...          ...        ...        ...             ...
# 1995         1.97         0.88       3.74       5.64          257.30
# 1996         2.87         0.67       3.01       5.26          269.25
# 1997         0.21         0.79       4.06       6.73          284.01
# 1998         0.17         1.06       2.94       9.45          119.25
# 1999         0.85         0.32       1.60       4.63           65.14
#
#       RelaxationTime  SleepTime
# 0               0.75       3.45
# 1               0.67       4.88
# 2               0.35       3.61
# ...

# %%
data.head()
# Out:
#    WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0         1.12         0.52       3.29       7.89          216.08
# 1         2.85         0.49       4.22       5.03          206.18
# 2         2.20         1.81       4.04       9.23           28.73
# 3         1.80         0.50       1.62       7.68          276.77
# 4         0.47         0.54       1.60       4.94          170.54
#
#    RelaxationTime  SleepTime
# 0            0.75       3.45
# 1            0.67       4.88
# 2            0.35       3.61
# 3            1.21       4.94
# 4            0.95       5.50

# %%
data.tail()
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 1995         1.97         0.88       3.74       5.64          257.30
# 1996         2.87         0.67       3.01       5.26          269.25
# 1997         0.21         0.79       4.06       6.73          284.01
# 1998         0.17         1.06       2.94       9.45          119.25
# 1999         0.85         0.32       1.60       4.63           65.14
#
#       RelaxationTime  SleepTime
# 1995            0.01       4.24
# 1996            1.75       5.89
# 1997            0.61       3.00
# 1998            1.88       3.53
# 1999            0.63       5.83

# %%
data.isnull().sum()
# Out:
# WorkoutTime       0
# ReadingTime       0
# PhoneTime         0
# WorkHours         0
# CaffeineIntake    0
# RelaxationTime    0
# SleepTime         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   WorkoutTime     2000 non-null   float64
#  1   ReadingTime     2000 non-null   float64
#  2   PhoneTime       2000 non-null   float64
#  3   WorkHours       2000 non-null   float64
#  4   CaffeineIntake  2000 non-null   float64
#  5   RelaxationTime  2000 non-null   float64
#  6   SleepTime       2000 non-null   float64
# dtypes: float64(7)
# memory usage: 109.5 KB

# %%
data.shape
# Out:
# (2000, 7)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.drop_duplicates()
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0            1.12         0.52       3.29       7.89          216.08
# 1            2.85         0.49       4.22       5.03          206.18
# 2            2.20         1.81       4.04       9.23           28.73
# 3            1.80         0.50       1.62       7.68          276.77
# 4            0.47         0.54       1.60       4.94          170.54
# ...           ...          ...        ...        ...             ...
# 1995         1.97         0.88       3.74       5.64          257.30
# 1996         2.87         0.67       3.01       5.26          269.25
# 1997         0.21         0.79       4.06       6.73          284.01
# 1998         0.17         1.06       2.94       9.45          119.25
# 1999         0.85         0.32       1.60       4.63           65.14
#
#       RelaxationTime  SleepTime
# 0               0.75       3.45
# 1               0.67       4.88
# 2               0.35       3.61
# ...

# %%
data.columns
# Out:
# Index(['WorkoutTime', 'ReadingTime', 'PhoneTime', 'WorkHours',
#        'CaffeineIntake', 'RelaxationTime', 'SleepTime'],
#       dtype='object')

# %%
data.dtypes
# Out:
# WorkoutTime       float64
# ReadingTime       float64
# PhoneTime         float64
# WorkHours         float64
# CaffeineIntake    float64
# RelaxationTime    float64
# SleepTime         float64
# dtype: object

# %%
data.describe()
# Out:
#        WorkoutTime  ReadingTime    PhoneTime    WorkHours  CaffeineIntake  \
# count  2000.000000  2000.000000  2000.000000  2000.000000     2000.000000
# mean      1.495915     0.992785     2.985195     6.926945      147.493780
# std       0.876639     0.577303     1.151776     1.723843       84.651139
# min       0.010000     0.000000     1.000000     4.000000        0.020000
# 25%       0.710000     0.500000     1.990000     5.440000       75.980000
# 50%       1.520000     0.990000     2.965000     6.910000      146.010000
# 75%       2.250000     1.500000     3.960000     8.422500      218.902500
# max       3.000000     2.000000     5.000000    10.000000      299.850000
#
#        RelaxationTime    SleepTime
# count     2000.000000  2000.000000
# mean         1.010955     4.884375
# std          0.582619     2.028892
# min          0.000000     0.150000
# 25%          0.510000     3.840000
# 50%          1.010000     4.600000
# 75%          1.530000     5.470000
# ...

# %%
100*25/100
# Out:
# 25.0

# %%
category=data[['WorkoutTime','ReadingTime','PhoneTime']]

# %%
category.describe()
# Out:
#        WorkoutTime  ReadingTime    PhoneTime
# count  2000.000000  2000.000000  2000.000000
# mean      1.495915     0.992785     2.985195
# std       0.876639     0.577303     1.151776
# min       0.010000     0.000000     1.000000
# 25%       0.710000     0.500000     1.990000
# 50%       1.520000     0.990000     2.965000
# 75%       2.250000     1.500000     3.960000
# max       3.000000     2.000000     5.000000

# %%
data['WorkoutTime'].unique()
# Out:
# array([1.12, 2.85, 2.2 , 1.8 , 0.47, 0.17, 2.6 , 2.12, 0.06, 2.91, 2.5 ,
#        0.64, 0.55, 0.91, 1.57, 1.3 , 0.87, 1.84, 0.42, 0.88, 1.1 , 1.37,
#        2.36, 0.6 , 1.54, 1.78, 0.14, 1.82, 0.51, 0.2 , 2.9 , 2.43, 0.29,
#        2.05, 1.32, 0.37, 1.49, 0.1 , 2.73, 0.78, 1.99, 0.94, 1.56, 1.64,
#        2.33, 2.82, 2.68, 1.79, 2.77, 0.27, 0.59, 0.98, 1.17, 0.81, 2.49,
#        1.07, 0.84, 1.63, 2.41, 0.22, 2.96, 2.32, 0.02, 2.45, 2.19, 2.31,
#        1.08, 0.35, 2.59, 1.87, 0.99, 0.19, 0.93, 1.91, 2.66, 1.42, 0.36,
#        2.14, 2.28, 1.68, 1.48, 1.28, 0.08, 0.32, 0.09, 1.53, 2.72, 0.75,
#        1.23, 2.27, 0.69, 0.23, 0.48, 2.79, 2.42, 1.9 , 2.61, 0.56, 1.62,
#        2.69, 0.95, 0.33, 0.68, 2.58, 1.25, 0.67, 1.01, 2.83, 0.97, 2.11,
#        1.09, 2.92, 2.89, 0.76, 0.9 , 0.85, 0.11, 1.83, 1.51, 0.15, 0.72,
#        0.43, 1.47, 0.73, 2.02, 0.71, 2.18, 1.61, 2.51, 0.96, 0.12, 1.77,
#        2.03, 0.05, 1.94, 0.52, 2.07, 1.16, 2.81, 0.41, 1.02, 0.34, 2.63,
# ...

# %%
data['SleepTime'].value_counts()
# Out:
# SleepTime
# 3.00    151
# 4.25     12
# 4.29     11
# 5.15     11
# 4.49     11
#        ...
# 7.14      1
# 7.21      1
# 3.04      1
# 8.71      1
# 7.48      1
# Name: count, Length: 475, dtype: int64

# %%
data['PhoneTime'].value_counts()
# Out:
# PhoneTime
# 2.37    13
# 3.31    12
# 1.20    11
# 1.16    11
# 3.26    11
#         ..
# 3.89     1
# 1.69     1
# 4.62     1
# 2.46     1
# 4.16     1
# Name: count, Length: 394, dtype: int64

# %%
data['SleepTime'].value_counts()
# Out:
# SleepTime
# 3.00    151
# 4.25     12
# 4.29     11
# 5.15     11
# 4.49     11
#        ...
# 7.14      1
# 7.21      1
# 3.04      1
# 8.71      1
# 7.48      1
# Name: count, Length: 475, dtype: int64

# %%
numerical_columns=data.select_dtypes(exclude='object').columns
categorical_columns=data.select_dtypes(include='object').columns

# %%
numerical_columns
# Out:
# Index(['WorkoutTime', 'ReadingTime', 'PhoneTime', 'WorkHours',
#        'CaffeineIntake', 'RelaxationTime', 'SleepTime'],
#       dtype='object')

# %%
categorical_columns
# Out:
# Index([], dtype='object')

# %%
data[numerical_columns]
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0            1.12         0.52       3.29       7.89          216.08
# 1            2.85         0.49       4.22       5.03          206.18
# 2            2.20         1.81       4.04       9.23           28.73
# 3            1.80         0.50       1.62       7.68          276.77
# 4            0.47         0.54       1.60       4.94          170.54
# ...           ...          ...        ...        ...             ...
# 1995         1.97         0.88       3.74       5.64          257.30
# 1996         2.87         0.67       3.01       5.26          269.25
# 1997         0.21         0.79       4.06       6.73          284.01
# 1998         0.17         1.06       2.94       9.45          119.25
# 1999         0.85         0.32       1.60       4.63           65.14
#
#       RelaxationTime  SleepTime
# 0               0.75       3.45
# 1               0.67       4.88
# 2               0.35       3.61
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
x=1
for i in numerical_columns:
    sns.histplot(data=data,x=i,kde=True)
    print('\n')
    plt.show()

# %%
x=1
for i in categorical_columns:
    sns.countplot(data=data,x=i)
    print('\n')
    plt.show()

# %%
sns.FacetGrid(data, hue="PhoneTime", height=5).map(sns.histplot, "SleepTime", kde=True).add_legend()
plt.title('Distribution of cut')
plt.xlabel('SleepTime')
plt.ylabel('PhoneTime')
plt.show()

# %%
numeric_df = data.select_dtypes(include=['float64', 'int64'])
sns.heatmap(numeric_df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
data['RelaxationTime']
# Out:
# 0       0.75
# 1       0.67
# 2       0.35
# 3       1.21
# 4       0.95
#         ...
# 1995    0.01
# 1996    1.75
# 1997    0.61
# 1998    1.88
# 1999    0.63
# Name: RelaxationTime, Length: 2000, dtype: float64

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
x=data.drop(columns=['SleepTime'],axis=1)
Y=data[['SleepTime']]

# %%
x
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0            1.12         0.52       3.29       7.89          216.08
# 1            2.85         0.49       4.22       5.03          206.18
# 2            2.20         1.81       4.04       9.23           28.73
# 3            1.80         0.50       1.62       7.68          276.77
# 4            0.47         0.54       1.60       4.94          170.54
# ...           ...          ...        ...        ...             ...
# 1995         1.97         0.88       3.74       5.64          257.30
# 1996         2.87         0.67       3.01       5.26          269.25
# 1997         0.21         0.79       4.06       6.73          284.01
# 1998         0.17         1.06       2.94       9.45          119.25
# 1999         0.85         0.32       1.60       4.63           65.14
#
#       RelaxationTime
# 0               0.75
# 1               0.67
# 2               0.35
# 3               1.21
# 4               0.95
# ...

# %%
Y
# Out:
#       SleepTime
# 0          3.45
# 1          4.88
# 2          3.61
# 3          4.94
# 4          5.50
# ...         ...
# 1995       4.24
# 1996       5.89
# 1997       3.00
# 1998       3.53
# 1999       5.83
#
# [2000 rows x 1 columns]

# %%
#Train test split

from sklearn.model_selection import train_test_split
x_train,x_test,Y_train,Y_test=train_test_split(x,Y,test_size=0.30,random_state=21)

# %%
regression=LinearRegression()
regression.fit(x_train,Y_train)
# Out:
# LinearRegression()

# %%
import numpy as np
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    r2_square = r2_score(true, predicted)
    return mae, r2_square,mse

# %%
models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet(),
}

for i in range (len(list((models)))):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
list(models.values())[2]
# Out:
# Ridge()

# %%
list(models.keys())[0]
# Out:
# 'LinearRegression'

# %%
models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet(),
}
trained_model_list=[]
model_list=[]
r2_list=[]

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(x_train,Y_train)

    #Make Predictions
    y_pred=model.predict(x_test)

    mae, r2_square,mse=evaluate_model(Y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])
    

    print('Model Training Performance')
   
    print("MAE:",mae)
    print("R2 score",r2_square)

    r2_list.append(r2_square)
    
    print('='*35)
    print('\n')
# Out:
# LinearRegression
# Model Training Performance
# MAE: 0.5826105678069147
# R2 score 0.2888779919648903
# ...
#
#
# Lasso
# Model Training Performance
# MAE: 1.163862092232178
# R2 score 0.010001886233134472
# ...
#
#
# Ridge
# Model Training Performance
# MAE: 0.5826347930360688
# R2 score 0.28886186072299835
# ...
#
#
# Elasticnet
# Model Training Performance
# MAE: 0.9932549320122712
# R2 score 0.12165687343007625
# ...

# %%
linear_regression=LinearRegression()
linear_regression.fit(x_train,Y_train)
# Out:
# LinearRegression()

# %%
import pickle

model_pkl_file="modellinear.pkl"

with open(model_pkl_file,'wb') as file:
    pickle.dump(linear_regression,file)

# %%
with open(model_pkl_file, 'rb') as file:  
    model = pickle.load(file)

# %%
x_train
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 1200         2.27         1.11       2.22       6.21          283.69
# 622          1.11         0.87       1.59       6.91          150.76
# 658          1.94         0.42       1.76       4.81           46.73
# 1990         2.30         0.17       1.05       7.93          135.11
# 310          1.32         1.01       2.11       6.17          143.03
# ...           ...          ...        ...        ...             ...
# 48           1.64         1.09       4.40       8.89          261.06
# 772          0.38         1.61       1.94       7.82          166.87
# 1848         2.66         1.43       2.28       4.71          177.33
# 1231         0.69         1.22       2.68       6.65           36.77
# 969          1.43         0.99       2.71       6.82           20.03
#
#       RelaxationTime
# 1200            0.45
# 622             1.23
# 658             0.89
# 1990            0.20
# 310             1.95
# ...

# %%
y_pred=model.predict(pd.DataFrame([[10,4,2,3,50,58]]))
# Out:
# c:\Users\lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_pred
# Out:
# array([[38.14641759]])
